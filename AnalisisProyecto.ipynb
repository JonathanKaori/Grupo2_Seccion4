# %%
import pandas as pd
DatosBitcoin = pd.read_csv("bitcoin.csv")
DatosValorUSD = pd.read_csv("USD_Exchange_Rates_2018_2024.csv")
DatosBancoCentral = pd.read_csv("InfoBancoCentral.csv",skiprows=4)
DatosBancoCentral = DatosBancoCentral.drop(DatosBancoCentral.columns[4:60], axis=1)
DatosBancoCentral = DatosBancoCentral.iloc[9:32]
#rows_to_read = list(range(9, 14)) + list(range(15, 27)) + list(range(28, 33))
DatosBancoCentral.info
# Out:
# <bound method DataFrame.info of    Country Name Country Code  \
# 9   El Salvador          SLV
# 10  El Salvador          SLV
# 11  El Salvador          SLV
# 12  El Salvador          SLV
# 13  El Salvador          SLV
# 14  El Salvador          SLV
# 15  El Salvador          SLV
# 16  El Salvador          SLV
# 17  El Salvador          SLV
# 18  El Salvador          SLV
# 19  El Salvador          SLV
# 20  El Salvador          SLV
# 21  El Salvador          SLV
# 22  El Salvador          SLV
# 23  El Salvador          SLV
# 24  El Salvador          SLV
# 25  El Salvador          SLV
# 26  El Salvador          SLV
# 27  El Salvador          SLV
# 28  El Salvador          SLV
# 29  El Salvador          SLV
# 30  El Salvador          SLV
# 31  El Salvador          SLV
#
#                                        Indicator Name        Indicator Code  \
# 9   Exportaciones de combustible (% de exportacion...     TX.VAL.FUEL.ZS.UN
# ...
