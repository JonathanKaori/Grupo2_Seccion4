# %%
import pandas as pd
DatosBitcoin = pd.read_csv("bitcoin.csv")
DatosBancoCentral = pd.read_csv("InfoBancoCentral.csv", skiprows=4, usecols=lambda col: col not in list(range(4, 48)))
DatosBancoCentralDTFiltrada = DatosBancoCentral.drop(DatosBancoCentral.columns[4:60], axis=1)
DatosBancoCentralDTFiltrada
# Out:
#      Country Name Country Code  \
# 0     El Salvador          SLV
# 1     El Salvador          SLV
# 2     El Salvador          SLV
# 3     El Salvador          SLV
# 4     El Salvador          SLV
# ...           ...          ...
# 1491  El Salvador          SLV
# 1492  El Salvador          SLV
# 1493  El Salvador          SLV
# 1494  El Salvador          SLV
# 1495  El Salvador          SLV
#
#                                          Indicator Name     Indicator Code  \
# 0        Intentional homicides, male (per 100,000 male)  VC.IHR.PSRC.MA.P5
# 1     Internally displaced persons, new displacement...        VC.IDP.NWCV
# 2     Voice and Accountability: Percentile Rank, Low...   VA.PER.RNK.LOWER
# 3     Servicios de viaje (% de las exportaciones de ...  TX.VAL.TRVL.ZS.WT
# 4     Exportaciones de servicios comerciales (US$ a ...  TX.VAL.SERV.CD.WT
# ...                                                 ...                ...
# ...
